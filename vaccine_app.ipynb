# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
pd.read_csv('data/india_vaccine.csv')
# Out:
#     Unnamed: 0        Date  Vaccine_total  Vaccine_male  Vaccine_female  \
# 0            0  2021-05-04      128627919      67265833        61344881
# 1            1  2021-05-05      129730641      67881167        61832097
# 2            2  2021-05-06      131058890      68616643        62424602
# 3            3  2021-05-07      132294827      69304346        62972623
# 4            4  2021-05-08      133366482      69899266        63449164
# 5            5  2021-05-09      133854676      70186220        63650307
# 6            6  2021-05-10      135192013      70948079        64225501
# 7            7  2021-05-11      136557345      71722365        64816275
# 8            8  2021-05-12      137805245      72431855        65354414
# 9            9  2021-05-13      139087590      73161834        65906538
# 10          10  2021-05-14      139861462      73607113        66234957
# 11          11  2021-05-15      141132112      74324379        66787921
# ...

# %%
df = pd.read_csv('data/india_vaccine.csv')

# %%
df
# Out:
#     Unnamed: 0        Date  Vaccine_total  Vaccine_male  Vaccine_female  \
# 0            0  2021-05-04      128627919      67265833        61344881
# 1            1  2021-05-05      129730641      67881167        61832097
# 2            2  2021-05-06      131058890      68616643        62424602
# 3            3  2021-05-07      132294827      69304346        62972623
# 4            4  2021-05-08      133366482      69899266        63449164
# 5            5  2021-05-09      133854676      70186220        63650307
# 6            6  2021-05-10      135192013      70948079        64225501
# 7            7  2021-05-11      136557345      71722365        64816275
# 8            8  2021-05-12      137805245      72431855        65354414
# 9            9  2021-05-13      139087590      73161834        65906538
# 10          10  2021-05-14      139861462      73607113        66234957
# 11          11  2021-05-15      141132112      74324379        66787921
# ...

# %%
df.rename(columns = {'Unnamed: 0':'dex'},inplace=True)

# %%
df
# Out:
#     index  dex        Date  Vaccine_total  Vaccine_male  Vaccine_female  \
# 0       0    0  2021-05-04      128627919      67265833        61344881
# 1       1    1  2021-05-05      129730641      67881167        61832097
# 2       2    2  2021-05-06      131058890      68616643        62424602
# 3       3    3  2021-05-07      132294827      69304346        62972623
# 4       4    4  2021-05-08      133366482      69899266        63449164
# 5       5    5  2021-05-09      133854676      70186220        63650307
# 6       6    6  2021-05-10      135192013      70948079        64225501
# 7       7    7  2021-05-11      136557345      71722365        64816275
# 8       8    8  2021-05-12      137805245      72431855        65354414
# 9       9    9  2021-05-13      139087590      73161834        65906538
# 10     10   10  2021-05-14      139861462      73607113        66234957
# 11     11   11  2021-05-15      141132112      74324379        66787921
# ...

# %%
df.set_index('dex',inplace=True)

# %%
df
# Out:
#      index        Date  Vaccine_total  Vaccine_male  Vaccine_female  \
# dex
# 0        0  2021-05-04      128627919      67265833        61344881
# 1        1  2021-05-05      129730641      67881167        61832097
# 2        2  2021-05-06      131058890      68616643        62424602
# 3        3  2021-05-07      132294827      69304346        62972623
# 4        4  2021-05-08      133366482      69899266        63449164
# 5        5  2021-05-09      133854676      70186220        63650307
# 6        6  2021-05-10      135192013      70948079        64225501
# 7        7  2021-05-11      136557345      71722365        64816275
# 8        8  2021-05-12      137805245      72431855        65354414
# 9        9  2021-05-13      139087590      73161834        65906538
# 10      10  2021-05-14      139861462      73607113        66234957
# 11      11  2021-05-15      141132112      74324379        66787921
# 12      12  2021-05-16      141764335      74693401        67050966
# ...

# %%
df.describe()
# Out:
#            index  Vaccine_total  Vaccine_male  Vaccine_female  Vaccine_others  \
# count  17.000000   1.700000e+01  1.700000e+01    1.700000e+01       17.000000
# mean    8.000000   1.376266e+08  7.234825e+07    6.525930e+07    19053.117647
# std     5.049752   5.619461e+06  3.200509e+06    2.417859e+06     1273.147865
# min     0.000000   1.286279e+08  6.726583e+07    6.134488e+07    17205.000000
# 25%     4.000000   1.333665e+08  6.989927e+07    6.344916e+07    18052.000000
# 50%     8.000000   1.378052e+08  7.243186e+07    6.535441e+07    18976.000000
# 75%    12.000000   1.417643e+08  7.469340e+07    6.705097e+07    19968.000000
# max    16.000000   1.466247e+08  7.751236e+07    6.909101e+07    21289.000000
#
#        Vaccine_covishield  Vaccine_covaxin  Vaccine_today  Vaccine_tot_dose1  \
# count        1.700000e+01     1.700000e+01   1.700000e+01       1.700000e+01
# mean         1.571235e+08     1.742889e+07   1.673806e+06       1.376266e+08
# ...

# %%
df.isna().sum()
# Out:
# index               0
# Date                0
# Vaccine_total       0
# Vaccine_male        0
# Vaccine_female      0
#                    ..
# Vaccine_total.1     0
# Vaccine_18_30       0
# Vaccine_30_45       0
# Vaccine_45_60       0
# Vaccine_above_60    0
# Length: 89, dtype: int64

# %%
df = df.loc[:,['Date','Vaccine_male','Vaccine_female','Vaccine_covishield','Vaccine_covaxin','Vaccine_aefi','aefiPercentage']]

# %%
#plotly 라이브러리
import plotly.express as px
px.bar(df, x='Date', y='Vaccine_male')
# Out:
# <div>                            <div id="18440f63-57a8-42ed-8443-8f2a8ee2e330" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18440f63-57a8-42ed-8443-8f2a8ee2e330")) {                    Plotly.newPlot(                        "18440f63-57a8-42ed-8443-8f2a8ee2e330",                        [{"alignmentgroup":"True","hovertemplate":"Date=%{x}<br>Vaccine_male=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2021-05-04","2021-05-05","2021-05-06","2021-05-07","2021-05-08","2021-05-09","2021-05-10","2021-05-11","2021-05-12","2021-05-13","2021-05-14","2021-05-15","2021-05-16","2021-05-17","2021-05-18","2021-05-19","2021-05-2
# ...

# %%
fig=px.histogram(df, x='Vaccine_male')
fig.update_layout(bargap=0.2)
# Out:
# <div>                            <div id="abe124d1-2523-4410-b248-58d76452f36a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("abe124d1-2523-4410-b248-58d76452f36a")) {                    Plotly.newPlot(                        "abe124d1-2523-4410-b248-58d76452f36a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Vaccine_male=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[67265833,67881167,68616643,69304346,69899266,70186220,70948079,71722365,72431855,73161834,73607113,74324379,74693401,75461311,76142110,76761977,77512357],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {
# ...

# %%
fig1=px.scatter_matrix(df,dimensions=['Vaccine_male','Vaccine_female','Vaccine_covishield','Vaccine_covaxin','Vaccine_aefi','aefiPercentage'])
fig1.update_layout(
    title='Data set',
    width=1500,
    height=1000,
)
# Out:
# <div>                            <div id="f2c63610-f66e-4a61-84f7-c281f49e80ad" class="plotly-graph-div" style="height:1000px; width:1500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2c63610-f66e-4a61-84f7-c281f49e80ad")) {                    Plotly.newPlot(                        "f2c63610-f66e-4a61-84f7-c281f49e80ad",                        [{"dimensions":[{"axis":{"matches":true},"label":"Vaccine_male","values":[67265833,67881167,68616643,69304346,69899266,70186220,70948079,71722365,72431855,73161834,73607113,74324379,74693401,75461311,76142110,76761977,77512357]},{"axis":{"matches":true},"label":"Vaccine_female","values":[61344881,61832097,62424602,62972623,63449164,63650307,64225501,64816275,65354414,65906538,66234957,66787921,67050966,67608590,68107465,68550747,69091006]},{"axis":{"matches":tr
# ...

# %%
plt.figure(figsize=(12,8))
sb.heatmap(data=df.loc[:,['Vaccine_male','Vaccine_female','Vaccine_covishield','Vaccine_covaxin','Vaccine_aefi','aefiPercentage']].corr(),annot=True,fmt='.2f',cmap='coolwarm',
          vmin = -1,vmax=1,linewidths=0.5)
plt.show()

# %%
X = df.loc[:,['Vaccine_male','Vaccine_female','Vaccine_covishield','Vaccine_covaxin']]
y = df['Vaccine_aefi']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size= 0.2, random_state= 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred =regressor.predict(X_test)

# %%
y_pred
# Out:
# array([20226.97977377, 20541.39388369, 20329.22145892, 20164.5276703 ])

# %%
plt.plot(y_test.values)
plt.plot(y_pred)
plt.legend( ['Real','Pred'] )
plt.show()

# %%
error=y_test-y_pred
(error**2).mean()
# Out:
# 4164.637978691214

# %%
import joblib
joblib.dump(regressor,'regressor.pkl')
# Out:
# ['regressor.pkl']

# %%
df.columns[1:6+1].sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [220], line 1
# ----> 1 df.columns[1:6+1].sum()
#
# AttributeError: 'Index' object has no attribute 'sum'

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [211], line 1
# ----> 1 df.columns[:,['Vaccine_male','Vaccine_female','Vaccine_covishield','Vaccine_covaxin','Vaccine_aefi','aefiPercentage']]
#
# File ~\Anaconda3\envs\YH\lib\site-packages\pandas\core\indexes\base.py:5069, in Index.__getitem__(self, key)
#    5062 if com.is_bool_indexer(key):
#    5063     # if we have list[bools, length=1e5] then doing this check+convert
#    5064     #  takes 166 µs + 2.1 ms and cuts the ndarray.__getitem__
#    5065     #  time below from 3.8 ms to 496 µs
#    5066     # if we already have ndarray[bool], the overhead is 1.4 µs or .25%
#    5067     key = np.asarray(key, dtype=bool)
# -> 5069 result = getitem(key)
#    5070 # Because we ruled out integer above, we always get an arraylike here
#    5071 if result.ndim > 1:
#
# ...

# %%
df2=df[['Vaccine_male','Vaccine_female','Vaccine_covishield','Vaccine_covaxin','Vaccine_aefi']].sum()

# %%
df2
# Out:
# Vaccine_male          1229920256
# Vaccine_female        1109408054
# Vaccine_covishield    2671099658
# Vaccine_covaxin        296291196
# Vaccine_aefi              345930
# dtype: int64
