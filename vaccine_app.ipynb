# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
pd.read_csv('data/india_vaccine.csv')
# Out:
#     Unnamed: 0        Date  Vaccine_total  Vaccine_male  Vaccine_female  \
# 0            0  2021-05-04      128627919      67265833        61344881
# 1            1  2021-05-05      129730641      67881167        61832097
# 2            2  2021-05-06      131058890      68616643        62424602
# 3            3  2021-05-07      132294827      69304346        62972623
# 4            4  2021-05-08      133366482      69899266        63449164
# 5            5  2021-05-09      133854676      70186220        63650307
# 6            6  2021-05-10      135192013      70948079        64225501
# 7            7  2021-05-11      136557345      71722365        64816275
# 8            8  2021-05-12      137805245      72431855        65354414
# 9            9  2021-05-13      139087590      73161834        65906538
# 10          10  2021-05-14      139861462      73607113        66234957
# 11          11  2021-05-15      141132112      74324379        66787921
# ...

# %%
df = pd.read_csv('data/india_vaccine.csv')

# %%
df
# Out:
#     Unnamed: 0        Date  Vaccine_total  Vaccine_male  Vaccine_female  \
# 0            0  2021-05-04      128627919      67265833        61344881
# 1            1  2021-05-05      129730641      67881167        61832097
# 2            2  2021-05-06      131058890      68616643        62424602
# 3            3  2021-05-07      132294827      69304346        62972623
# 4            4  2021-05-08      133366482      69899266        63449164
# 5            5  2021-05-09      133854676      70186220        63650307
# 6            6  2021-05-10      135192013      70948079        64225501
# 7            7  2021-05-11      136557345      71722365        64816275
# 8            8  2021-05-12      137805245      72431855        65354414
# 9            9  2021-05-13      139087590      73161834        65906538
# 10          10  2021-05-14      139861462      73607113        66234957
# 11          11  2021-05-15      141132112      74324379        66787921
# ...

# %%
df.set_index('Unnamed: 0',inplace=True)

# %%
df = df.reset_index()

# %%
df
# Out:
#     Unnamed: 0        Date  Vaccine_total  Vaccine_male  Vaccine_female  \
# 0            0  2021-05-04      128627919      67265833        61344881
# 1            1  2021-05-05      129730641      67881167        61832097
# 2            2  2021-05-06      131058890      68616643        62424602
# 3            3  2021-05-07      132294827      69304346        62972623
# 4            4  2021-05-08      133366482      69899266        63449164
# 5            5  2021-05-09      133854676      70186220        63650307
# 6            6  2021-05-10      135192013      70948079        64225501
# 7            7  2021-05-11      136557345      71722365        64816275
# 8            8  2021-05-12      137805245      72431855        65354414
# 9            9  2021-05-13      139087590      73161834        65906538
# 10          10  2021-05-14      139861462      73607113        66234957
# 11          11  2021-05-15      141132112      74324379        66787921
# ...

# %%
df.rename(columns = {'Unnamed: 0':'dex'},inplace=True)

# %%
df
# Out:
#     dex        Date  Vaccine_total  Vaccine_male  Vaccine_female  \
# 0     0  2021-05-04      128627919      67265833        61344881
# 1     1  2021-05-05      129730641      67881167        61832097
# 2     2  2021-05-06      131058890      68616643        62424602
# 3     3  2021-05-07      132294827      69304346        62972623
# 4     4  2021-05-08      133366482      69899266        63449164
# 5     5  2021-05-09      133854676      70186220        63650307
# 6     6  2021-05-10      135192013      70948079        64225501
# 7     7  2021-05-11      136557345      71722365        64816275
# 8     8  2021-05-12      137805245      72431855        65354414
# 9     9  2021-05-13      139087590      73161834        65906538
# 10   10  2021-05-14      139861462      73607113        66234957
# 11   11  2021-05-15      141132112      74324379        66787921
# 12   12  2021-05-16      141764335      74693401        67050966
# ...

# %%
df.set_index('dex',inplace=True)

# %%
df
# Out:
#            Date  Vaccine_total  Vaccine_male  Vaccine_female  Vaccine_others  \
# dex
# 0    2021-05-04      128627919      67265833        61344881           17205
# 1    2021-05-05      129730641      67881167        61832097           17377
# 2    2021-05-06      131058890      68616643        62424602           17645
# 3    2021-05-07      132294827      69304346        62972623           17858
# 4    2021-05-08      133366482      69899266        63449164           18052
# 5    2021-05-09      133854676      70186220        63650307           18149
# 6    2021-05-10      135192013      70948079        64225501           18433
# 7    2021-05-11      136557345      71722365        64816275           18705
# 8    2021-05-12      137805245      72431855        65354414           18976
# 9    2021-05-13      139087590      73161834        65906538           19218
# 10   2021-05-14      139861462      73607113        66234957           19392
# ...

# %%
df.describe()
# Out:
#        Vaccine_total  Vaccine_male  Vaccine_female  Vaccine_others  \
# count   1.700000e+01  1.700000e+01    1.700000e+01       17.000000
# mean    1.376266e+08  7.234825e+07    6.525930e+07    19053.117647
# std     5.619461e+06  3.200509e+06    2.417859e+06     1273.147865
# min     1.286279e+08  6.726583e+07    6.134488e+07    17205.000000
# 25%     1.333665e+08  6.989927e+07    6.344916e+07    18052.000000
# 50%     1.378052e+08  7.243186e+07    6.535441e+07    18976.000000
# 75%     1.417643e+08  7.469340e+07    6.705097e+07    19968.000000
# max     1.466247e+08  7.751236e+07    6.909101e+07    21289.000000
#
#        Vaccine_covishield  Vaccine_covaxin  Vaccine_today  Vaccine_tot_dose1  \
# count        1.700000e+01     1.700000e+01   1.700000e+01       1.700000e+01
# mean         1.571235e+08     1.742889e+07   1.673806e+06       1.376266e+08
# std          8.032896e+06     1.649109e+06   5.710330e+05       5.619461e+06
# ...

# %%
df.loc[:,[]'Vaccine_total','Vaccine_male','Vaccine_female','Vaccine_covishield','Vaccine_covaxin','Vaccine_aefi','aefiPercentage']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\envs\YH\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\Anaconda3\envs\YH\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\envs\YH\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Vaccine_total', 'Vaccine_male', 'Vaccine_female', 'Vaccine_covishield', 'Vaccine_covaxin', 'Vaccine_aefi', 'aefiPercentage')
#
# ...

# %%
df.isna().sum()
# Out:
# Date                0
# Vaccine_total       0
# Vaccine_male        0
# Vaccine_female      0
# Vaccine_others      0
#                    ..
# Vaccine_total.1     0
# Vaccine_18_30       0
# Vaccine_30_45       0
# Vaccine_45_60       0
# Vaccine_above_60    0
# Length: 88, dtype: int64

# %%
plt.figure(figsize=(50,50))
sb.heatmap(data=df.corr(),annot=True,fmt='.2f',cmap='coolwarm',
          vmin = -1,vmax=1,linewidths=0.5)
plt.show()
